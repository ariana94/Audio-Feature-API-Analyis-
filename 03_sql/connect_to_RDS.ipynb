# %%
from sqlalchemy import create_engine
import pandas as pd
import config

# %%
# connection credentials for the 'top40' Amazon RDS Postgres database
db_name = 'top40'
db_url = 'top40.cext0azslr6v.us-west-1.rds.amazonaws.com'
db_username = 'postgres'
db_port = '5432'
db_password = config.db_password

# %%
# connect to the database
# https://docs.sqlalchemy.org/en/14/core/engines.html#database-urls
# SQLalchemy connection format: dialect+driver://username:password@host:port/database

# create a connection string
db_string = f"postgresql://{db_username}:{db_password}@{db_url}/{db_name}"

# create an engine
engine = create_engine(db_string)

# %%
# read in a dataframe
# tables in the database are 'songs', 'charts'

songs = pd.read_sql_query('select * from songs', con=engine)
songs.head()
# Out:
#                                combo           artist                 song  \
# 0                    Hanson: Mmm Bop           Hanson              Mmm Bop
# 1             Meredith Brooks: Bitch  Meredith Brooks                Bitch
# 2   Spice Girls: Say You'll Be There      Spice Girls  Say You'll Be There
# 3  Mark Morrison: Return Of The Mack    Mark Morrison   Return Of The Mack
# 4      Shawn Colvin: Sunny Came Home     Shawn Colvin      Sunny Came Home
#
#                 artist_id                 song_id  acousticness  danceability  \
# 0  0SdiiPkr02EUdekHZJkt58  0lnxrQAd9ZxbhBBe7d8FO8       0.00481         0.683
# 1  2QmLFuIDtNDmmJY3OtvinN  3i6qNxyVgIdUZTTi5m25EM       0.01120         0.617
# 2  0uq5PttqEjj3IH1bzwcrXF  1yTQ39my3MoNROlFw3RDNy       0.01490         0.726
# 3  6V3F8MZrOKdT9fU686ybE9  3jDdpx9PMlfMBS5tOBHFm9       0.00631         0.715
# 4  0K7VN4aHxHcEb7PqkfoIVA  4mOxpj82q6n3EO7HBZCelX       0.34200         0.558
#
# ...
